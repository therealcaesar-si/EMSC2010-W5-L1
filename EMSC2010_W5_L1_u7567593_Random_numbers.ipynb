# %% [markdown]
# <a href="https://colab.research.google.com/github/therealcaesar-si/EMSC2010-W5-L1/blob/main/EMSC2010_W5_L1_u7567593_Random_numbers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #EMSC2010-W5-L1
#
# ## Random numbers
# Below is some simple code to *generate uniformly* distributed random numbers. Don't worry about how the code works, we're just going to use it to demonstrate a concept.

# %%
class SimpleRNG:
    """
    A Linear Congruential Generator (LCG).
    Formula: next = (a * current + c) % m
    """
    def __init__(self, seed=42):
        self.state = seed
        self.a = 1664525      # Multiplier
        self.c = 1013904223   # Increment
        self.m = 2**32        # Modulus

    def next_int(self):
        """Generate the next raw integer."""
        self.state = (self.a * self.state + self.c) % self.m
        return self.state

    def next_float(self):
        """Generate a float in [0, 1)."""
        return self.next_int() / self.m

# %% [markdown]
# Generate 5 random numbers using a *seed* and print them to the screen

# %%
rng1 = SimpleRNG(seed=99)
for _ in range(5):
    print(f"  rng1: {rng1.next_float():.6f}")
# Out:
#   rng1: 0.274436
#   rng1: 0.258240
#   rng1: 0.605653
#   rng1: 0.332487
#   rng1: 0.364237

# %% [markdown]
# ### Using Numpy
# Rather than writing our own code, we typically use a package like ```numpy``` to generate random numbers.

# %%
import numpy as np

# Create a generator with a fixed seed
rng = np.random.default_rng(seed=99)

# Generate an array of 5 numbers in [0, 1)
print(rng.uniform(size=5))

# Generate numbers in a custom range, e.g. [10, 20)
print(rng.uniform(low=10, high=20, size=5))
# Out:
# [0.50603067 0.56509163 0.51191596 0.97218637 0.61490314]
# [15.68283498 12.86786723 15.54511453 14.67523526 16.10058008]

# %%
x = rng.uniform(size=100000)

# %%
import matplotlib.pyplot as plt
plt.hist(x, bins=50)
plt.show()
#create a histogram with bins grouping how often numbers appear

# %% [markdown]
# They are fairly flat at the top becuase it is uniformly distributed.

# %%
Ntot = 10000000 #Number of darts thrown = 1000
X = rng.uniform(size=Ntot)
Y = rng.uniform(size=Ntot)
D = np.sqrt((X-0.5)**2 + (Y-0.5)**2) # distance between points and the centre of circle
Nc = np.sum(D<0.5) # number of darts in circle
plt.plot(X,Y,'.')
plt.show()
print(Nc)
Ac = Nc/Ntot #Area of the circle
print(Ac)

print(np.pi*0.5**2) #Print actual area of the circle
#
# Out:
# 7854008
# 0.7854008
# 0.7853981633974483

# %%
Ntot = 1000 #Number of darts thrown = 1000
X = rng.uniform(size=Ntot)
Y = rng.uniform(size=Ntot)
W = rng.uniform(size=Ntot) #3d now
Z = rng.uniform(size=Ntot) #4d now

D = np.sqrt((X-0.5)**2 + (Y-0.5)**2 + (W-0.5)**2 +(Z-0.5)**2) # distance between points and the centre of the hypersphere
Nc = np.sum(D<0.5) # number of darts in circle
#plt.plot(X,Y,'.')
#plt.show()
# dont try to visualise a 4d hypersphere
print(Nc)
Ac = Nc/Ntot #Area of the circle
print(Ac)

#print(np.pi*0.5**2) #Print actual area of the circle
#this one is obsolete now
# Out:
# 320
# 0.32
